# %% [markdown]
# <a href="https://colab.research.google.com/github/bymyself-yoon/datory_lab/blob/main/Data_Sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("filterd_data.csv", encoding='utf-8')

# %%
data
# Out:
#       strd_date  strd_tizn_val ifw_rgn_dv_val vehi_size_dv_val  \
# 0      20230901              0             내부               대형
# 1      20230901              0             내부               소형
# 2      20230901              0             내부               중형
# 3      20230901              0             내부               중형
# 4      20230901              1             내부               대형
# ...         ...            ...            ...              ...
# 3739   20230927             23             내부               대형
# 3740   20230927             23             내부               대형
# 3741   20230927             23             내부               소형
# 3742   20230927             23             내부               중형
# 3743   20230927             23             내부               중형
#
#      vehi_typ_dv_val  vehi_num  pass_nt
# 0                 승용        15       15
# 1                 화물         1        1
# 2                 승용        29       29
# 3                 승합         1        1
# ...

# %%
date = 20230901
sum_data = 0
max_data = 0
min_data = 10000

while(date < 20230928):
  # 조건을 만족하는 행을 필터링
  filtered_data = data[data['strd_date'] == date]

  # vehi_num의 합계를 계산
  sum_data = filtered_data['vehi_num'].sum()

  if(sum_data > max_data):
    max_data = sum_data
    max_date = date
  elif(sum_data < min_data):
    min_data = sum_data
    min_date = date

  date += 1

min_data, min_date, max_data, max_date
# Out:
# (2288, 20230922, 8157, 20230923)

# %%
min_filtered_data = data[data['strd_date'] == min_date]

min_filtered_data
# Out:
#       strd_date  strd_tizn_val ifw_rgn_dv_val vehi_size_dv_val  \
# 2917   20230922              0             내부               대형
# 2918   20230922              0             내부               소형
# 2919   20230922              0             내부               중형
# 2920   20230922              0             내부               중형
# 2921   20230922              1             내부               대형
# ...         ...            ...            ...              ...
# 3032   20230922             22             내부               소형
# 3033   20230922             22             내부               중형
# 3034   20230922             23             내부               대형
# 3035   20230922             23             내부               소형
# 3036   20230922             23             내부               중형
#
#      vehi_typ_dv_val  vehi_num  pass_nt
# 2917              승용         3        3
# 2918              화물         1        1
# 2919              승용         6        6
# 2920              화물         2        2
# ...

# %%
max_filtered_data = data[data['strd_date'] == max_date]

max_filtered_data
# Out:
#       strd_date  strd_tizn_val ifw_rgn_dv_val vehi_size_dv_val  \
# 3037   20230923              0             내부               대형
# 3038   20230923              0             내부               소형
# 3039   20230923              0             내부               중형
# 3040   20230923              0             내부               중형
# 3041   20230923              0             내부               중형
# ...         ...            ...            ...              ...
# 3197   20230923             23             내부               대형
# 3198   20230923             23             내부               대형
# 3199   20230923             23             내부               대형
# 3200   20230923             23             내부               소형
# 3201   20230923             23             내부               중형
#
#      vehi_typ_dv_val  vehi_num  pass_nt
# 3037              승용        26       26
# 3038              화물         6        6
# 3039              승용        58       58
# 3040              승합         2        2
# ...

# %%
# Save csv file
min_filtered_data.to_csv('min_filtered_data.csv', index=False, encoding='utf-8-sig')
max_filtered_data.to_csv('max_filtered_data.csv', index=False, encoding='utf-8-sig')

# %%
v_sizes = ['대형', '중형', '소형', '경형']
v_types = ['승용', '승합', '특수', '화물']
time_count = 0

# 조건을 개별적으로 작성
condition1 = data['vehi_size_dv_val'] == v_size[0]
condition2 = data['vehi_typ_dv_val'] == v_type[0]
condition3 = data['strd_tizn_val'] == time_count

# 조건을 결합하여 필터링
f_data = data[condition1 & condition2 & condition3]

avg_data = f_data['vehi_num'].sum() / len(f_data)

avg_data

while time_count < 24:
  for v_size in v_sizes:
    for v_types in v_type:
# Out:
# 15.62962962962963
